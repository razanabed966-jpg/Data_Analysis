# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/AI/Data Analysis/student/students_exans.csv")
df.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
gender = df["gender"]
gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
math = df["math score"]
math
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
students = df[["gender", "math score"]]
students
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
rows = df[2:7]
rows
# Out:
#    gender  math score  reading score  writing score
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75
# 5  female          71             83             78
# 6  female          88             95             92

# %%
result = df.loc[0]
result
# Out:
# gender           female
# math score           72
# reading score        72
# writing score        74
# Name: 0, dtype: object

# %%
result = df.loc[[1, 3, 999], ['gender']]
result
# Out:
#      gender
# 1    female
# 3      male
# 999  female

# %%
result = df.loc[:, ['gender']]
result
# Out:
#      gender
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# ..      ...
# 995  female
# 996    male
# 997  female
# 998  female
# 999  female
#
# [1000 rows x 1 columns]

# %%
result = df.loc[15:30, ['gender', 'math score']]
result
# Out:
#     gender  math score
# 15  female          69
# 16    male          88
# 17  female          18
# 18    male          46
# 19  female          54
# 20    male          66
# 21  female          65
# 22    male          44
# 23  female          69
# 24    male          74
# 25    male          73
# 26    male          69
# 27  female          67
# 28    male          70
# 29  female          62
# 30  female          69

# %%
result = df.iloc[0]
result
# Out:
# gender           female
# math score           72
# reading score        72
# writing score        74
# Name: 0, dtype: object

# %%
result = df.loc[[1, 999], ['gender', 'math score']]
result
# Out:
#      gender  math score
# 1    female          69
# 999  female          77
