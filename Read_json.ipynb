# %%
import pandas as pd

df = pd.read_json('/content/drive/MyDrive/AI/Data Analysis/movies.json')
df
# Out:
#                                       title  year  \
# 0                After Dark in Central Park  1900
# 1      Boarding School Girls' Pajama Parade  1900
# 2            Buffalo Bill's Wild West Parad  1900
# 3                                    Caught  1900
# 4                      Clowns Spinning Hats  1900
# ...                                     ...   ...
# 28790                             Bumblebee  2018
# 28791                     Welcome to Marwen  2018
# 28792                     Holmes and Watson  2018
# 28793                   On the Basis of Sex  2018
# 28794                             Destroyer  2018
#
#                                                     cast  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...

# %%
df.shape
# Out:
# (28795, 4)

# %%
import pandas as pd

# Step 1: Read the full JSON file
df_full = pd.read_json('/content/drive/MyDrive/AI/Data Analysis/movies.json')

# Step 2: Select specific columns
df = df_full[['title', 'year']]

df.head()
# Out:
#                                   title  year
# 0            After Dark in Central Park  1900
# 1  Boarding School Girls' Pajama Parade  1900
# 2        Buffalo Bill's Wild West Parad  1900
# 3                                Caught  1900
# 4                  Clowns Spinning Hats  1900

# %%
df.tail()
# Out:
#                      title  year
# 28790            Bumblebee  2018
# 28791    Welcome to Marwen  2018
# 28792    Holmes and Watson  2018
# 28793  On the Basis of Sex  2018
# 28794            Destroyer  2018
