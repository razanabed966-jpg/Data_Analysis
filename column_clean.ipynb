# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/AI/Data Analysis/student/students_exans.csv")
df.head()
# Out:
#    gender  math score  reading score  writing score
# 0  female          72             72             74
# 1  female          69             90             88
# 2  female          90             95             93
# 3    male          47             57             44
# 4    male          76             78             75

# %%
for row in df.itertuples():
    print(row)
# Out:
# Pandas(Index=0, gender='female', _2=72, _3=72, _4=74)
# Pandas(Index=1, gender='female', _2=69, _3=90, _4=88)
# Pandas(Index=2, gender='female', _2=90, _3=95, _4=93)
# Pandas(Index=3, gender='male', _2=47, _3=57, _4=44)
# Pandas(Index=4, gender='male', _2=76, _3=78, _4=75)
# Pandas(Index=5, gender='female', _2=71, _3=83, _4=78)
# Pandas(Index=6, gender='female', _2=88, _3=95, _4=92)
# Pandas(Index=7, gender='male', _2=40, _3=43, _4=39)
# Pandas(Index=8, gender='male', _2=64, _3=64, _4=67)
# Pandas(Index=9, gender='female', _2=38, _3=60, _4=50)
# Pandas(Index=10, gender='male', _2=58, _3=54, _4=52)
# Pandas(Index=11, gender='male', _2=40, _3=52, _4=43)
# Pandas(Index=12, gender='female', _2=65, _3=81, _4=73)
# Pandas(Index=13, gender='male', _2=78, _3=72, _4=70)
# Pandas(Index=14, gender='female', _2=50, _3=53, _4=58)
# Pandas(Index=15, gender='female', _2=69, _3=75, _4=78)
# Pandas(Index=16, gender='male', _2=88, _3=89, _4=86)
# Pandas(Index=17, gender='female', _2=18, _3=32, _4=28)
# Pandas(Index=18, gender='male', _2=46, _3=42, _4=46)
# Pandas(Index=19, gender='female', _2=54, _3=58, _4=61)
# Pandas(Index=20, gender='male', _2=66, _3=69, _4=63)
# Pandas(Index=21, gender='female', _2=65, _3=75, _4=70)
# Pandas(Index=22, gender='male', _2=44, _3=54, _4=53)
# Pandas(Index=23, gender='female', _2=69, _3=73, _4=73)
# Pandas(Index=24, gender='male', _2=74, _3=71, _4=80)
# Pandas(Index=25, gender='male', _2=73, _3=74, _4=72)
# Pandas(Index=26, gender='male', _2=69, _3=54, _4=55)
# Pandas(Index=27, gender='female', _2=67, _3=69, _4=75)
# Pandas(Index=28, gender='male', _2=70, _3=70, _4=65)
# Pandas(Index=29, gender='female', _2=62, _3=70, _4=75)
# Pandas(Index=30, gender='female', _2=69, _3=74, _4=74)
# Pandas(Index=31, gender='female', _2=63, _3=65, _4=61)
# Pandas(Index=32, gender='female', _2=56, _3=72, _4=65)
# Pandas(Index=33, gender='male', _2=40, _3=42, _4=38)
# Pandas(Index=34, gender='male', _2=97, _3=87, _4=82)
# Pandas(Index=35, gender='male', _2=81, _3=81, _4=79)
# Pandas(Index=36, gender='female', _2=74, _3=81, _4=83)
# Pandas(Index=37, gender='female', _2=50, _3=64, _4=59)
# Pandas(Index=38, gender='female', _2=75, _3=90, _4=88)
# Pandas(Index=39, gender='male', _2=57, _3=56, _4=57)
# Pandas(Index=40, gender='male', _2=55, _3=61, _4=54)
# Pandas(Index=41, gender='female', _2=58, _3=73, _4=68)
# Pandas(Index=42, gender='female', _2=53, _3=58, _4=65)
# Pandas(Index=43, gender='male', _2=59, _3=65, _4=66)
# Pandas(Index=44, gender='female', _2=50, _3=56, _4=54)
# Pandas(Index=45, gender='male', _2=65, _3=54, _4=57)
# Pandas(Index=46, gender='female', _2=55, _3=65, _4=62)
# Pandas(Index=47, gender='female', _2=66, _3=71, _4=76)
# Pandas(Index=48, gender='female', _2=57, _3=74, _4=76)
# Pandas(Index=49, gender='male', _2=82, _3=84, _4=82)
# Pandas(Index=50, gender='male', _2=53, _3=55, _4=48)
# Pandas(Index=51, gender='male', _2=77, _3=69, _4=68)
# Pandas(Index=52, gender='male', _2=53, _3=44, _4=42)
# Pandas(Index=53, gender='male', _2=88, _3=78, _4=75)
# Pandas(Index=54, gender='female', _2=71, _3=84, _4=87)
# Pandas(Index=55, gender='female', _2=33, _3=41, _4=43)
# Pandas(Index=56, gender='female', _2=82, _3=85, _4=86)
# Pandas(Index=57, gender='male', _2=52, _3=55, _4=49)
# Pandas(Index=58, gender='male', _2=58, _3=59, _4=58)
# Pandas(Index=59, gender='female', _2=0, _3=17, _4=10)
# Pandas(Index=60, gender='male', _2=79, _3=74, _4=72)
# Pandas(Index=61, gender='male', _2=39, _3=39, _4=34)
# Pandas(Index=62, gender='male', _2=62, _3=61, _4=55)
# Pandas(Index=63, gender='female', _2=69, _3=80, _4=71)
# Pandas(Index=64, gender='female', _2=59, _3=58, _4=59)
# Pandas(Index=65, gender='male', _2=67, _3=64, _4=61)
# Pandas(Index=66, gender='male', _2=45, _3=37, _4=37)
# Pandas(Index=67, gender='female', _2=60, _3=72, _4=74)
# Pandas(Index=68, gender='male', _2=61, _3=58, _4=56)
# Pandas(Index=69, gender='female', _2=39, _3=64, _4=57)
# Pandas(Index=70, gender='female', _2=58, _3=63, _4=73)
# Pandas(Index=71, gender='male', _2=63, _3=55, _4=63)
# Pandas(Index=72, gender='female', _2=41, _3=51, _4=48)
# Pandas(Index=73, gender='male', _2=61, _3=57, _4=56)
# Pandas(Index=74, gender='male', _2=49, _3=49, _4=41)
# Pandas(Index=75, gender='male', _2=44, _3=41, _4=38)
# Pandas(Index=76, gender='male', _2=30, _3=26, _4=22)
# Pandas(Index=77, gender='male', _2=80, _3=78, _4=81)
# Pandas(Index=78, gender='female', _2=61, _3=74, _4=72)
# Pandas(Index=79, gender='female', _2=62, _3=68, _4=68)
# Pandas(Index=80, gender='female', _2=47, _3=49, _4=50)
# Pandas(Index=81, gender='male', _2=49, _3=45, _4=45)
# Pandas(Index=82, gender='male', _2=50, _3=47, _4=54)
# Pandas(Index=83, gender='male', _2=72, _3=64, _4=63)
# Pandas(Index=84, gender='male', _2=42, _3=39, _4=34)
# Pandas(Index=85, gender='female', _2=73, _3=80, _4=82)
# Pandas(Index=86, gender='female', _2=76, _3=83, _4=88)
# Pandas(Index=87, gender='female', _2=71, _3=71, _4=74)
# Pandas(Index=88, gender='female', _2=58, _3=70, _4=67)
# Pandas(Index=89, gender='female', _2=73, _3=86, _4=82)
# Pandas(Index=90, gender='female', _2=65, _3=72, _4=74)
# Pandas(Index=91, gender='male', _2=27, _3=34, _4=36)
# Pandas(Index=92, gender='male', _2=71, _3=79, _4=71)
# Pandas(Index=93, gender='male', _2=43, _3=45, _4=50)
# Pandas(Index=94, gender='female', _2=79, _3=86, _4=92)
# Pandas(Index=95, gender='male', _2=78, _3=81, _4=82)
# Pandas(Index=96, gender='male', _2=65, _3=66, _4=62)
# Pandas(Index=97, gender='female', _2=63, _3=72, _4=70)
# Pandas(Index=98, gender='female', _2=58, _3=67, _4=62)
# Pandas(Index=99, gender='female', _2=65, _3=67, _4=62)
# Pandas(Index=100, gender='male', _2=79, _3=67, _4=67)
# Pandas(Index=101, gender='male', _2=68, _3=74, _4=74)
# Pandas(Index=102, gender='female', _2=85, _3=91, _4=89)
# Pandas(Index=103, gender='male', _2=60, _3=44, _4=47)
# Pandas(Index=104, gender='male', _2=98, _3=86, _4=90)
# Pandas(Index=105, gender='female', _2=58, _3=67, _4=72)
# Pandas(Index=106, gender='female', _2=87, _3=100, _4=100)
# Pandas(Index=107, gender='male', _2=66, _3=63, _4=64)
# Pandas(Index=108, gender='female', _2=52, _3=76, _4=70)
# Pandas(Index=109, gender='female', _2=70, _3=64, _4=72)
# Pandas(Index=110, gender='female', _2=77, _3=89, _4=98)
# Pandas(Index=111, gender='male', _2=62, _3=55, _4=49)
# Pandas(Index=112, gender='male', _2=54, _3=53, _4=47)
# Pandas(Index=113, gender='female', _2=51, _3=58, _4=54)
# Pandas(Index=114, gender='female', _2=99, _3=100, _4=100)
# Pandas(Index=115, gender='male', _2=84, _3=77, _4=74)
# Pandas(Index=116, gender='female', _2=75, _3=85, _4=82)
# Pandas(Index=117, gender='female', _2=78, _3=82, _4=79)
# Pandas(Index=118, gender='female', _2=51, _3=63, _4=61)
# Pandas(Index=119, gender='female', _2=55, _3=69, _4=65)
# Pandas(Index=120, gender='female', _2=79, _3=92, _4=89)
# Pandas(Index=121, gender='male', _2=91, _3=89, _4=92)
# Pandas(Index=122, gender='female', _2=88, _3=93, _4=93)
# Pandas(Index=123, gender='male', _2=63, _3=57, _4=56)
# Pandas(Index=124, gender='male', _2=83, _3=80, _4=73)
# Pandas(Index=125, gender='female', _2=87, _3=95, _4=86)
# Pandas(Index=126, gender='male', _2=72, _3=68, _4=67)
# Pandas(Index=127, gender='male', _2=65, _3=77, _4=74)
# Pandas(Index=128, gender='male', _2=82, _3=82, _4=74)
# Pandas(Index=129, gender='female', _2=51, _3=49, _4=51)
# Pandas(Index=130, gender='male', _2=89, _3=84, _4=82)
# Pandas(Index=131, gender='male', _2=53, _3=37, _4=40)
# Pandas(Index=132, gender='male', _2=87, _3=74, _4=70)
# Pandas(Index=133, gender='female', _2=75, _3=81, _4=84)
# Pandas(Index=134, gender='male', _2=74, _3=79, _4=75)
# Pandas(Index=135, gender='male', _2=58, _3=55, _4=48)
# Pandas(Index=136, gender='male', _2=51, _3=54, _4=41)
# Pandas(Index=137, gender='male', _2=70, _3=55, _4=56)
# Pandas(Index=138, gender='female', _2=59, _3=66, _4=67)
# Pandas(Index=139, gender='male', _2=71, _3=61, _4=69)
# Pandas(Index=140, gender='female', _2=76, _3=72, _4=71)
# Pandas(Index=141, gender='female', _2=59, _3=62, _4=64)
# Pandas(Index=142, gender='female', _2=42, _3=55, _4=54)
# Pandas(Index=143, gender='male', _2=57, _3=43, _4=47)
# Pandas(Index=144, gender='male', _2=88, _3=73, _4=78)
# Pandas(Index=145, gender='female', _2=22, _3=39, _4=33)
# Pandas(Index=146, gender='male', _2=88, _3=84, _4=75)
# Pandas(Index=147, gender='male', _2=73, _3=68, _4=66)
# Pandas(Index=148, gender='female', _2=68, _3=75, _4=81)
# Pandas(Index=149, gender='male', _2=100, _3=100, _4=93)
# Pandas(Index=150, gender='male', _2=62, _3=67, _4=69)
# Pandas(Index=151, gender='male', _2=77, _3=67, _4=68)
# Pandas(Index=152, gender='female', _2=59, _3=70, _4=66)
# Pandas(Index=153, gender='male', _2=54, _3=49, _4=47)
# Pandas(Index=154, gender='male', _2=62, _3=67, _4=61)
# Pandas(Index=155, gender='female', _2=70, _3=89, _4=88)
# Pandas(Index=156, gender='female', _2=66, _3=74, _4=78)
# Pandas(Index=157, gender='male', _2=60, _3=60, _4=60)
# Pandas(Index=158, gender='female', _2=61, _3=86, _4=87)
# Pandas(Index=159, gender='male', _2=66, _3=62, _4=64)
# Pandas(Index=160, gender='male', _2=82, _3=78, _4=74)
# Pandas(Index=161, gender='female', _2=75, _3=88, _4=85)
# Pandas(Index=162, gender='male', _2=49, _3=53, _4=52)
# Pandas(Index=163, gender='male', _2=52, _3=53, _4=49)
# Pandas(Index=164, gender='female', _2=81, _3=92, _4=91)
# Pandas(Index=165, gender='female', _2=96, _3=100, _4=100)
# Pandas(Index=166, gender='male', _2=53, _3=51, _4=51)
# Pandas(Index=167, gender='female', _2=58, _3=76, _4=78)
# Pandas(Index=168, gender='female', _2=68, _3=83, _4=78)
# Pandas(Index=169, gender='female', _2=67, _3=75, _4=70)
# Pandas(Index=170, gender='male', _2=72, _3=73, _4=74)
# Pandas(Index=171, gender='male', _2=94, _3=88, _4=78)
# Pandas(Index=172, gender='female', _2=79, _3=86, _4=81)
# Pandas(Index=173, gender='female', _2=63, _3=67, _4=70)
# Pandas(Index=174, gender='female', _2=43, _3=51, _4=54)
# Pandas(Index=175, gender='female', _2=81, _3=91, _4=87)
# Pandas(Index=176, gender='female', _2=46, _3=54, _4=58)
# Pandas(Index=177, gender='female', _2=71, _3=77, _4=77)
# Pandas(Index=178, gender='female', _2=52, _3=70, _4=62)
# Pandas(Index=179, gender='female', _2=97, _3=100, _4=100)
# Pandas(Index=180, gender='male', _2=62, _3=68, _4=75)
# Pandas(Index=181, gender='female', _2=46, _3=64, _4=66)
# Pandas(Index=182, gender='female', _2=50, _3=50, _4=47)
# Pandas(Index=183, gender='female', _2=65, _3=69, _4=70)
# Pandas(Index=184, gender='male', _2=45, _3=52, _4=49)
# Pandas(Index=185, gender='male', _2=65, _3=67, _4=65)
# Pandas(Index=186, gender='male', _2=80, _3=76, _4=65)
# Pandas(Index=187, gender='male', _2=62, _3=66, _4=68)
# Pandas(Index=188, gender='male', _2=48, _3=52, _4=45)
# Pandas(Index=189, gender='female', _2=77, _3=88, _4=87)
# Pandas(Index=190, gender='female', _2=66, _3=65, _4=69)
# Pandas(Index=191, gender='male', _2=76, _3=83, _4=79)
# Pandas(Index=192, gender='female', _2=62, _3=64, _4=66)
# Pandas(Index=193, gender='male', _2=77, _3=62, _4=62)
# Pandas(Index=194, gender='female', _2=69, _3=84, _4=85)
# Pandas(Index=195, gender='male', _2=61, _3=55, _4=52)
# Pandas(Index=196, gender='male', _2=59, _3=69, _4=65)
# Pandas(Index=197, gender='male', _2=55, _3=56, _4=51)
# Pandas(Index=198, gender='female', _2=45, _3=53, _4=55)
# Pandas(Index=199, gender='female', _2=78, _3=79, _4=76)
# Pandas(Index=200, gender='female', _2=67, _3=84, _4=86)
# Pandas(Index=201, gender='female', _2=65, _3=81, _4=77)
# Pandas(Index=202, gender='male', _2=69, _3=77, _4=69)
# Pandas(Index=203, gender='female', _2=57, _3=69, _4=68)
# Pandas(Index=204, gender='male', _2=59, _3=41, _4=42)
# Pandas(Index=205, gender='male', _2=74, _3=71, _4=78)
# Pandas(Index=206, gender='male', _2=82, _3=62, _4=62)
# Pandas(Index=207, gender='male', _2=81, _3=80, _4=76)
# Pandas(Index=208, gender='female', _2=74, _3=81, _4=76)
# Pandas(Index=209, gender='female', _2=58, _3=61, _4=66)
# Pandas(Index=210, gender='male', _2=80, _3=79, _4=79)
# Pandas(Index=211, gender='male', _2=35, _3=28, _4=27)
# Pandas(Index=212, gender='female', _2=42, _3=62, _4=60)
# Pandas(Index=213, gender='male', _2=60, _3=51, _4=56)
# Pandas(Index=214, gender='male', _2=87, _3=91, _4=81)
# Pandas(Index=215, gender='male', _2=84, _3=83, _4=75)
# Pandas(Index=216, gender='female', _2=83, _3=86, _4=88)
# Pandas(Index=217, gender='female', _2=34, _3=42, _4=39)
# Pandas(Index=218, gender='male', _2=66, _3=77, _4=70)
# Pandas(Index=219, gender='male', _2=61, _3=56, _4=56)
# Pandas(Index=220, gender='female', _2=56, _3=68, _4=74)
# Pandas(Index=221, gender='male', _2=87, _3=85, _4=73)
# Pandas(Index=222, gender='female', _2=55, _3=65, _4=62)
# Pandas(Index=223, gender='male', _2=86, _3=80, _4=75)
# Pandas(Index=224, gender='female', _2=52, _3=66, _4=73)
# Pandas(Index=225, gender='female', _2=45, _3=56, _4=54)
# Pandas(Index=226, gender='female', _2=72, _3=72, _4=71)
# Pandas(Index=227, gender='male', _2=57, _3=50, _4=54)
# Pandas(Index=228, gender='male', _2=68, _3=72, _4=64)
# Pandas(Index=229, gender='female', _2=88, _3=95, _4=94)
# Pandas(Index=230, gender='male', _2=76, _3=64, _4=66)
# Pandas(Index=231, gender='male', _2=46, _3=43, _4=42)
# Pandas(Index=232, gender='female', _2=67, _3=86, _4=83)
# Pandas(Index=233, gender='male', _2=92, _3=87, _4=78)
# Pandas(Index=234, gender='male', _2=83, _3=82, _4=84)
# Pandas(Index=235, gender='male', _2=80, _3=75, _4=77)
# Pandas(Index=236, gender='male', _2=63, _3=66, _4=67)
# Pandas(Index=237, gender='female', _2=64, _3=60, _4=74)
# Pandas(Index=238, gender='male', _2=54, _3=52, _4=51)
# Pandas(Index=239, gender='male', _2=84, _3=80, _4=80)
# Pandas(Index=240, gender='male', _2=73, _3=68, _4=66)
# Pandas(Index=241, gender='female', _2=80, _3=83, _4=83)
# Pandas(Index=242, gender='female', _2=56, _3=52, _4=55)
# Pandas(Index=243, gender='male', _2=59, _3=51, _4=43)
# Pandas(Index=244, gender='male', _2=75, _3=74, _4=69)
# Pandas(Index=245, gender='male', _2=85, _3=76, _4=71)
# Pandas(Index=246, gender='male', _2=89, _3=76, _4=74)
# Pandas(Index=247, gender='female', _2=58, _3=70, _4=68)
# Pandas(Index=248, gender='female', _2=65, _3=64, _4=62)
# Pandas(Index=249, gender='male', _2=68, _3=60, _4=53)
# Pandas(Index=250, gender='male', _2=47, _3=49, _4=49)
# Pandas(Index=251, gender='female', _2=71, _3=83, _4=83)
# Pandas(Index=252, gender='female', _2=60, _3=70, _4=70)
# Pandas(Index=253, gender='male', _2=80, _3=80, _4=72)
# Pandas(Index=254, gender='male', _2=54, _3=52, _4=52)
# Pandas(Index=255, gender='female', _2=62, _3=73, _4=70)
# Pandas(Index=256, gender='female', _2=64, _3=73, _4=68)
# Pandas(Index=257, gender='male', _2=78, _3=77, _4=77)
# Pandas(Index=258, gender='female', _2=70, _3=75, _4=78)
# Pandas(Index=259, gender='female', _2=65, _3=81, _4=81)
# Pandas(Index=260, gender='female', _2=64, _3=79, _4=77)
# Pandas(Index=261, gender='male', _2=79, _3=79, _4=78)
# Pandas(Index=262, gender='female', _2=44, _3=50, _4=51)
# Pandas(Index=263, gender='female', _2=99, _3=93, _4=90)
# Pandas(Index=264, gender='male', _2=76, _3=73, _4=68)
# Pandas(Index=265, gender='male', _2=59, _3=42, _4=41)
# Pandas(Index=266, gender='female', _2=63, _3=75, _4=81)
# Pandas(Index=267, gender='female', _2=69, _3=72, _4=77)
# Pandas(Index=268, gender='female', _2=88, _3=92, _4=95)
# Pandas(Index=269, gender='female', _2=71, _3=76, _4=70)
# Pandas(Index=270, gender='male', _2=69, _3=63, _4=61)
# Pandas(Index=271, gender='male', _2=58, _3=49, _4=42)
# Pandas(Index=272, gender='female', _2=47, _3=53, _4=58)
# Pandas(Index=273, gender='female', _2=65, _3=70, _4=71)
# Pandas(Index=274, gender='male', _2=88, _3=85, _4=76)
# Pandas(Index=275, gender='male', _2=83, _3=78, _4=73)
# Pandas(Index=276, gender='female', _2=85, _3=92, _4=93)
# Pandas(Index=277, gender='female', _2=59, _3=63, _4=75)
# Pandas(Index=278, gender='female', _2=65, _3=86, _4=80)
# Pandas(Index=279, gender='male', _2=73, _3=56, _4=57)
# Pandas(Index=280, gender='male', _2=53, _3=52, _4=42)
# Pandas(Index=281, gender='male', _2=45, _3=48, _4=46)
# Pandas(Index=282, gender='female', _2=73, _3=79, _4=84)
# Pandas(Index=283, gender='female', _2=70, _3=78, _4=78)
# Pandas(Index=284, gender='female', _2=37, _3=46, _4=46)
# Pandas(Index=285, gender='male', _2=81, _3=82, _4=82)
# Pandas(Index=286, gender='male', _2=97, _3=82, _4=88)
# Pandas(Index=287, gender='female', _2=67, _3=89, _4=82)
# Pandas(Index=288, gender='male', _2=88, _3=75, _4=76)
# Pandas(Index=289, gender='male', _2=77, _3=76, _4=77)
# Pandas(Index=290, gender='male', _2=76, _3=70, _4=68)
# Pandas(Index=291, gender='male', _2=86, _3=73, _4=70)
# Pandas(Index=292, gender='male', _2=63, _3=60, _4=57)
# Pandas(Index=293, gender='female', _2=65, _3=73, _4=75)
# Pandas(Index=294, gender='male', _2=78, _3=77, _4=80)
# Pandas(Index=295, gender='male', _2=67, _3=62, _4=60)
# Pandas(Index=296, gender='male', _2=46, _3=41, _4=43)
# Pandas(Index=297, gender='male', _2=71, _3=74, _4=68)
# Pandas(Index=298, gender='male', _2=40, _3=46, _4=50)
# Pandas(Index=299, gender='male', _2=90, _3=87, _4=75)
# Pandas(Index=300, gender='male', _2=81, _3=78, _4=81)
# Pandas(Index=301, gender='male', _2=56, _3=54, _4=52)
# Pandas(Index=302, gender='female', _2=67, _3=84, _4=81)
# Pandas(Index=303, gender='male', _2=80, _3=76, _4=64)
# Pandas(Index=304, gender='female', _2=74, _3=75, _4=83)
# Pandas(Index=305, gender='male', _2=69, _3=67, _4=69)
# Pandas(Index=306, gender='male', _2=99, _3=87, _4=81)
# Pandas(Index=307, gender='male', _2=51, _3=52, _4=44)
# Pandas(Index=308, gender='female', _2=53, _3=71, _4=67)
# Pandas(Index=309, gender='female', _2=49, _3=57, _4=52)
# Pandas(Index=310, gender='female', _2=73, _3=76, _4=80)
# Pandas(Index=311, gender='male', _2=66, _3=60, _4=57)
# Pandas(Index=312, gender='male', _2=67, _3=61, _4=68)
# Pandas(Index=313, gender='female', _2=68, _3=67, _4=69)
# Pandas(Index=314, gender='female', _2=59, _3=64, _4=75)
# Pandas(Index=315, gender='male', _2=71, _3=66, _4=65)
# Pandas(Index=316, gender='female', _2=77, _3=82, _4=91)
# Pandas(Index=317, gender='male', _2=83, _3=72, _4=78)
# Pandas(Index=318, gender='male', _2=63, _3=71, _4=69)
# Pandas(Index=319, gender='female', _2=56, _3=65, _4=63)
# Pandas(Index=320, gender='female', _2=67, _3=79, _4=84)
# Pandas(Index=321, gender='female', _2=75, _3=86, _4=79)
# Pandas(Index=322, gender='female', _2=71, _3=81, _4=80)
# Pandas(Index=323, gender='female', _2=43, _3=53, _4=53)
# Pandas(Index=324, gender='female', _2=41, _3=46, _4=43)
# Pandas(Index=325, gender='female', _2=82, _3=90, _4=94)
# Pandas(Index=326, gender='male', _2=61, _3=61, _4=62)
# Pandas(Index=327, gender='male', _2=28, _3=23, _4=19)
# Pandas(Index=328, gender='male', _2=82, _3=75, _4=77)
# Pandas(Index=329, gender='female', _2=41, _3=55, _4=51)
# Pandas(Index=330, gender='male', _2=71, _3=60, _4=61)
# Pandas(Index=331, gender='male', _2=47, _3=37, _4=35)
# Pandas(Index=332, gender='male', _2=62, _3=56, _4=53)
# Pandas(Index=333, gender='male', _2=90, _3=78, _4=81)
# Pandas(Index=334, gender='female', _2=83, _3=93, _4=95)
# Pandas(Index=335, gender='female', _2=61, _3=68, _4=66)
# Pandas(Index=336, gender='male', _2=76, _3=70, _4=69)
# Pandas(Index=337, gender='male', _2=49, _3=51, _4=43)
# Pandas(Index=338, gender='female', _2=24, _3=38, _4=27)
# Pandas(Index=339, gender='female', _2=35, _3=55, _4=60)
# Pandas(Index=340, gender='male', _2=58, _3=61, _4=52)
# Pandas(Index=341, gender='female', _2=61, _3=73, _4=63)
# Pandas(Index=342, gender='female', _2=69, _3=76, _4=74)
# Pandas(Index=343, gender='male', _2=67, _3=72, _4=67)
# Pandas(Index=344, gender='male', _2=79, _3=73, _4=67)
# Pandas(Index=345, gender='female', _2=72, _3=80, _4=75)
# Pandas(Index=346, gender='male', _2=62, _3=61, _4=57)
# Pandas(Index=347, gender='female', _2=77, _3=94, _4=95)
# Pandas(Index=348, gender='male', _2=75, _3=74, _4=66)
# Pandas(Index=349, gender='male', _2=87, _3=74, _4=76)
# Pandas(Index=350, gender='female', _2=52, _3=65, _4=69)
# Pandas(Index=351, gender='male', _2=66, _3=57, _4=52)
# Pandas(Index=352, gender='female', _2=63, _3=78, _4=80)
# Pandas(Index=353, gender='female', _2=46, _3=58, _4=57)
# Pandas(Index=354, gender='female', _2=59, _3=71, _4=70)
# Pandas(Index=355, gender='female', _2=61, _3=72, _4=70)
# Pandas(Index=356, gender='male', _2=63, _3=61, _4=61)
# Pandas(Index=357, gender='female', _2=42, _3=66, _4=69)
# Pandas(Index=358, gender='male', _2=59, _3=62, _4=61)
# Pandas(Index=359, gender='female', _2=80, _3=90, _4=89)
# Pandas(Index=360, gender='female', _2=58, _3=62, _4=59)
# Pandas(Index=361, gender='male', _2=85, _3=84, _4=78)
# Pandas(Index=362, gender='female', _2=52, _3=58, _4=58)
# Pandas(Index=363, gender='female', _2=27, _3=34, _4=32)
# Pandas(Index=364, gender='male', _2=59, _3=60, _4=58)
# Pandas(Index=365, gender='male', _2=49, _3=58, _4=60)
# Pandas(Index=366, gender='male', _2=69, _3=58, _4=53)
# Pandas(Index=367, gender='male', _2=61, _3=66, _4=61)
# Pandas(Index=368, gender='female', _2=44, _3=64, _4=58)
# Pandas(Index=369, gender='female', _2=73, _3=84, _4=85)
# Pandas(Index=370, gender='male', _2=84, _3=77, _4=71)
# Pandas(Index=371, gender='female', _2=45, _3=73, _4=70)
# Pandas(Index=372, gender='male', _2=74, _3=74, _4=72)
# Pandas(Index=373, gender='female', _2=82, _3=97, _4=96)
# Pandas(Index=374, gender='female', _2=59, _3=70, _4=73)
# Pandas(Index=375, gender='male', _2=46, _3=43, _4=41)
# Pandas(Index=376, gender='female', _2=80, _3=90, _4=82)
# Pandas(Index=377, gender='female', _2=85, _3=95, _4=100)
# Pandas(Index=378, gender='female', _2=71, _3=83, _4=77)
# Pandas(Index=379, gender='male', _2=66, _3=64, _4=62)
# Pandas(Index=380, gender='female', _2=80, _3=86, _4=83)
# Pandas(Index=381, gender='male', _2=87, _3=100, _4=95)
# Pandas(Index=382, gender='male', _2=79, _3=81, _4=71)
# Pandas(Index=383, gender='female', _2=38, _3=49, _4=45)
# Pandas(Index=384, gender='female', _2=38, _3=43, _4=43)
# Pandas(Index=385, gender='female', _2=67, _3=76, _4=75)
# Pandas(Index=386, gender='female', _2=64, _3=73, _4=70)
# Pandas(Index=387, gender='female', _2=57, _3=78, _4=67)
# Pandas(Index=388, gender='female', _2=62, _3=64, _4=64)
# Pandas(Index=389, gender='male', _2=73, _3=70, _4=75)
# Pandas(Index=390, gender='male', _2=73, _3=67, _4=59)
# Pandas(Index=391, gender='female', _2=77, _3=68, _4=77)
# Pandas(Index=392, gender='male', _2=76, _3=67, _4=67)
# Pandas(Index=393, gender='male', _2=57, _3=54, _4=56)
# Pandas(Index=394, gender='female', _2=65, _3=74, _4=77)
# Pandas(Index=395, gender='male', _2=48, _3=45, _4=41)
# Pandas(Index=396, gender='female', _2=50, _3=67, _4=63)
# Pandas(Index=397, gender='female', _2=85, _3=89, _4=95)
# Pandas(Index=398, gender='male', _2=74, _3=63, _4=57)
# Pandas(Index=399, gender='male', _2=60, _3=59, _4=54)
# Pandas(Index=400, gender='female', _2=59, _3=54, _4=67)
# Pandas(Index=401, gender='male', _2=53, _3=43, _4=43)
# Pandas(Index=402, gender='female', _2=49, _3=65, _4=55)
# Pandas(Index=403, gender='female', _2=88, _3=99, _4=100)
# Pandas(Index=404, gender='female', _2=54, _3=59, _4=62)
# Pandas(Index=405, gender='female', _2=63, _3=73, _4=68)
# Pandas(Index=406, gender='male', _2=65, _3=65, _4=63)
# Pandas(Index=407, gender='female', _2=82, _3=80, _4=77)
# Pandas(Index=408, gender='female', _2=52, _3=57, _4=56)
# Pandas(Index=409, gender='male', _2=87, _3=84, _4=85)
# Pandas(Index=410, gender='female', _2=70, _3=71, _4=74)
# Pandas(Index=411, gender='male', _2=84, _3=83, _4=78)
# Pandas(Index=412, gender='male', _2=71, _3=66, _4=60)
# Pandas(Index=413, gender='male', _2=63, _3=67, _4=67)
# Pandas(Index=414, gender='female', _2=51, _3=72, _4=79)
# Pandas(Index=415, gender='male', _2=84, _3=73, _4=69)
# Pandas(Index=416, gender='male', _2=71, _3=74, _4=68)
# Pandas(Index=417, gender='male', _2=74, _3=73, _4=67)
# Pandas(Index=418, gender='male', _2=68, _3=59, _4=62)
# Pandas(Index=419, gender='male', _2=57, _3=56, _4=54)
# Pandas(Index=420, gender='female', _2=82, _3=93, _4=93)
# Pandas(Index=421, gender='female', _2=57, _3=58, _4=64)
# Pandas(Index=422, gender='female', _2=47, _3=58, _4=67)
# Pandas(Index=423, gender='female', _2=59, _3=85, _4=80)
# Pandas(Index=424, gender='male', _2=41, _3=39, _4=34)
# Pandas(Index=425, gender='female', _2=62, _3=67, _4=62)
# Pandas(Index=426, gender='male', _2=86, _3=83, _4=86)
# Pandas(Index=427, gender='male', _2=69, _3=71, _4=65)
# Pandas(Index=428, gender='male', _2=65, _3=59, _4=53)
# Pandas(Index=429, gender='male', _2=68, _3=63, _4=54)
# Pandas(Index=430, gender='male', _2=64, _3=66, _4=59)
# Pandas(Index=431, gender='female', _2=61, _3=72, _4=70)
# Pandas(Index=432, gender='male', _2=61, _3=56, _4=55)
# Pandas(Index=433, gender='female', _2=47, _3=59, _4=50)
# Pandas(Index=434, gender='male', _2=73, _3=66, _4=66)
# Pandas(Index=435, gender='male', _2=50, _3=48, _4=53)
# Pandas(Index=436, gender='male', _2=75, _3=68, _4=64)
# Pandas(Index=437, gender='male', _2=75, _3=66, _4=73)
# Pandas(Index=438, gender='male', _2=70, _3=56, _4=51)
# Pandas(Index=439, gender='male', _2=89, _3=88, _4=82)
# Pandas(Index=440, gender='female', _2=67, _3=81, _4=79)
# Pandas(Index=441, gender='female', _2=78, _3=81, _4=80)
# Pandas(Index=442, gender='female', _2=59, _3=73, _4=69)
# Pandas(Index=443, gender='female', _2=73, _3=83, _4=76)
# Pandas(Index=444, gender='male', _2=79, _3=82, _4=73)
# Pandas(Index=445, gender='female', _2=67, _3=74, _4=77)
# Pandas(Index=446, gender='male', _2=69, _3=66, _4=60)
# Pandas(Index=447, gender='male', _2=86, _3=81, _4=80)
# Pandas(Index=448, gender='male', _2=47, _3=46, _4=42)
# Pandas(Index=449, gender='male', _2=81, _3=73, _4=72)
# Pandas(Index=450, gender='female', _2=64, _3=85, _4=85)
# Pandas(Index=451, gender='female', _2=100, _3=92, _4=97)
# Pandas(Index=452, gender='female', _2=65, _3=77, _4=74)
# Pandas(Index=453, gender='male', _2=65, _3=58, _4=49)
# Pandas(Index=454, gender='female', _2=53, _3=61, _4=62)
# Pandas(Index=455, gender='male', _2=37, _3=56, _4=47)
# Pandas(Index=456, gender='female', _2=79, _3=89, _4=89)
# Pandas(Index=457, gender='male', _2=53, _3=54, _4=48)
# Pandas(Index=458, gender='female', _2=100, _3=100, _4=100)
# Pandas(Index=459, gender='male', _2=72, _3=65, _4=68)
# Pandas(Index=460, gender='male', _2=53, _3=58, _4=55)
# Pandas(Index=461, gender='male', _2=54, _3=54, _4=45)
# Pandas(Index=462, gender='female', _2=71, _3=70, _4=76)
# Pandas(Index=463, gender='female', _2=77, _3=90, _4=91)
# Pandas(Index=464, gender='male', _2=75, _3=58, _4=62)
# Pandas(Index=465, gender='female', _2=84, _3=87, _4=91)
# Pandas(Index=466, gender='female', _2=26, _3=31, _4=38)
# Pandas(Index=467, gender='male', _2=72, _3=67, _4=65)
# Pandas(Index=468, gender='female', _2=77, _3=88, _4=85)
# Pandas(Index=469, gender='male', _2=91, _3=74, _4=76)
# Pandas(Index=470, gender='female', _2=83, _3=85, _4=90)
# Pandas(Index=471, gender='female', _2=63, _3=69, _4=74)
# Pandas(Index=472, gender='female', _2=68, _3=86, _4=84)
# Pandas(Index=473, gender='female', _2=59, _3=67, _4=61)
# Pandas(Index=474, gender='female', _2=90, _3=90, _4=91)
# Pandas(Index=475, gender='female', _2=71, _3=76, _4=83)
# Pandas(Index=476, gender='male', _2=76, _3=62, _4=66)
# Pandas(Index=477, gender='male', _2=80, _3=68, _4=72)
# Pandas(Index=478, gender='female', _2=55, _3=64, _4=70)
# Pandas(Index=479, gender='male', _2=76, _3=71, _4=67)
# Pandas(Index=480, gender='male', _2=73, _3=71, _4=68)
# Pandas(Index=481, gender='female', _2=52, _3=59, _4=56)
# Pandas(Index=482, gender='male', _2=68, _3=68, _4=61)
# Pandas(Index=483, gender='male', _2=59, _3=52, _4=46)
# Pandas(Index=484, gender='female', _2=49, _3=52, _4=54)
# Pandas(Index=485, gender='male', _2=70, _3=74, _4=71)
# Pandas(Index=486, gender='male', _2=61, _3=47, _4=56)
# Pandas(Index=487, gender='female', _2=60, _3=75, _4=74)
# Pandas(Index=488, gender='male', _2=64, _3=53, _4=57)
# Pandas(Index=489, gender='male', _2=79, _3=82, _4=82)
# Pandas(Index=490, gender='female', _2=65, _3=85, _4=76)
# Pandas(Index=491, gender='female', _2=64, _3=64, _4=70)
# Pandas(Index=492, gender='female', _2=83, _3=83, _4=90)
# Pandas(Index=493, gender='female', _2=81, _3=88, _4=90)
# Pandas(Index=494, gender='female', _2=54, _3=64, _4=68)
# Pandas(Index=495, gender='male', _2=68, _3=64, _4=66)
# Pandas(Index=496, gender='female', _2=54, _3=48, _4=52)
# Pandas(Index=497, gender='female', _2=59, _3=78, _4=76)
# Pandas(Index=498, gender='female', _2=66, _3=69, _4=68)
# Pandas(Index=499, gender='male', _2=76, _3=71, _4=72)
# Pandas(Index=500, gender='female', _2=74, _3=79, _4=82)
# Pandas(Index=501, gender='female', _2=94, _3=87, _4=92)
# Pandas(Index=502, gender='male', _2=63, _3=61, _4=54)
# Pandas(Index=503, gender='female', _2=95, _3=89, _4=92)
# Pandas(Index=504, gender='female', _2=40, _3=59, _4=54)
# Pandas(Index=505, gender='female', _2=82, _3=82, _4=80)
# Pandas(Index=506, gender='male', _2=68, _3=70, _4=66)
# Pandas(Index=507, gender='male', _2=55, _3=59, _4=54)
# Pandas(Index=508, gender='male', _2=79, _3=78, _4=77)
# Pandas(Index=509, gender='female', _2=86, _3=92, _4=87)
# Pandas(Index=510, gender='male', _2=76, _3=71, _4=73)
# Pandas(Index=511, gender='male', _2=64, _3=50, _4=43)
# Pandas(Index=512, gender='male', _2=62, _3=49, _4=52)
# Pandas(Index=513, gender='female', _2=54, _3=61, _4=62)
# Pandas(Index=514, gender='female', _2=77, _3=97, _4=94)
# Pandas(Index=515, gender='female', _2=76, _3=87, _4=85)
# Pandas(Index=516, gender='female', _2=74, _3=89, _4=84)
# Pandas(Index=517, gender='female', _2=66, _3=74, _4=73)
# Pandas(Index=518, gender='female', _2=66, _3=78, _4=78)
# Pandas(Index=519, gender='female', _2=67, _3=78, _4=79)
# Pandas(Index=520, gender='male', _2=71, _3=49, _4=52)
# Pandas(Index=521, gender='female', _2=91, _3=86, _4=84)
# Pandas(Index=522, gender='male', _2=69, _3=58, _4=57)
# Pandas(Index=523, gender='male', _2=54, _3=59, _4=50)
# Pandas(Index=524, gender='male', _2=53, _3=52, _4=49)
# Pandas(Index=525, gender='male', _2=68, _3=60, _4=59)
# Pandas(Index=526, gender='male', _2=56, _3=61, _4=60)
# Pandas(Index=527, gender='female', _2=36, _3=53, _4=43)
# Pandas(Index=528, gender='female', _2=29, _3=41, _4=47)
# Pandas(Index=529, gender='female', _2=62, _3=74, _4=70)
# Pandas(Index=530, gender='female', _2=68, _3=67, _4=73)
# Pandas(Index=531, gender='female', _2=47, _3=54, _4=53)
# Pandas(Index=532, gender='male', _2=62, _3=61, _4=58)
# Pandas(Index=533, gender='female', _2=79, _3=88, _4=94)
# Pandas(Index=534, gender='male', _2=73, _3=69, _4=68)
# Pandas(Index=535, gender='female', _2=66, _3=83, _4=83)
# Pandas(Index=536, gender='male', _2=51, _3=60, _4=58)
# Pandas(Index=537, gender='female', _2=51, _3=66, _4=62)
# Pandas(Index=538, gender='male', _2=85, _3=66, _4=71)
# Pandas(Index=539, gender='male', _2=97, _3=92, _4=86)
# Pandas(Index=540, gender='male', _2=75, _3=69, _4=68)
# Pandas(Index=541, gender='male', _2=79, _3=82, _4=80)
# Pandas(Index=542, gender='female', _2=81, _3=77, _4=79)
# Pandas(Index=543, gender='female', _2=82, _3=95, _4=89)
# Pandas(Index=544, gender='female', _2=64, _3=63, _4=66)
# Pandas(Index=545, gender='male', _2=78, _3=83, _4=80)
# Pandas(Index=546, gender='female', _2=92, _3=100, _4=97)
# Pandas(Index=547, gender='male', _2=72, _3=67, _4=64)
# Pandas(Index=548, gender='female', _2=62, _3=67, _4=64)
# Pandas(Index=549, gender='male', _2=79, _3=72, _4=69)
# Pandas(Index=550, gender='male', _2=79, _3=76, _4=65)
# Pandas(Index=551, gender='male', _2=87, _3=90, _4=88)
# Pandas(Index=552, gender='female', _2=40, _3=48, _4=50)
# Pandas(Index=553, gender='male', _2=77, _3=62, _4=64)
# Pandas(Index=554, gender='male', _2=53, _3=45, _4=40)
# Pandas(Index=555, gender='female', _2=32, _3=39, _4=33)
# Pandas(Index=556, gender='female', _2=55, _3=72, _4=79)
# Pandas(Index=557, gender='male', _2=61, _3=67, _4=66)
# Pandas(Index=558, gender='female', _2=53, _3=70, _4=70)
# Pandas(Index=559, gender='male', _2=73, _3=66, _4=62)
# Pandas(Index=560, gender='female', _2=74, _3=75, _4=79)
# Pandas(Index=561, gender='female', _2=63, _3=74, _4=74)
# Pandas(Index=562, gender='male', _2=96, _3=90, _4=92)
# Pandas(Index=563, gender='female', _2=63, _3=80, _4=80)
# Pandas(Index=564, gender='male', _2=48, _3=51, _4=46)
# Pandas(Index=565, gender='male', _2=48, _3=43, _4=45)
# Pandas(Index=566, gender='female', _2=92, _3=100, _4=100)
# Pandas(Index=567, gender='female', _2=61, _3=71, _4=78)
# Pandas(Index=568, gender='male', _2=63, _3=48, _4=47)
# Pandas(Index=569, gender='male', _2=68, _3=68, _4=67)
# Pandas(Index=570, gender='male', _2=71, _3=75, _4=70)
# Pandas(Index=571, gender='male', _2=91, _3=96, _4=92)
# Pandas(Index=572, gender='female', _2=53, _3=62, _4=56)
# Pandas(Index=573, gender='female', _2=50, _3=66, _4=64)
# Pandas(Index=574, gender='female', _2=74, _3=81, _4=71)
# Pandas(Index=575, gender='male', _2=40, _3=55, _4=53)
# Pandas(Index=576, gender='male', _2=61, _3=51, _4=52)
# Pandas(Index=577, gender='female', _2=81, _3=91, _4=89)
# Pandas(Index=578, gender='female', _2=48, _3=56, _4=58)
# Pandas(Index=579, gender='female', _2=53, _3=61, _4=68)
# Pandas(Index=580, gender='female', _2=81, _3=97, _4=96)
# Pandas(Index=581, gender='female', _2=77, _3=79, _4=80)
# Pandas(Index=582, gender='female', _2=63, _3=73, _4=78)
# Pandas(Index=583, gender='female', _2=73, _3=75, _4=80)
# Pandas(Index=584, gender='female', _2=69, _3=77, _4=77)
# Pandas(Index=585, gender='female', _2=65, _3=76, _4=76)
# Pandas(Index=586, gender='female', _2=55, _3=73, _4=73)
# Pandas(Index=587, gender='female', _2=44, _3=63, _4=62)
# Pandas(Index=588, gender='female', _2=54, _3=64, _4=65)
# Pandas(Index=589, gender='female', _2=48, _3=66, _4=65)
# Pandas(Index=590, gender='male', _2=58, _3=57, _4=54)
# Pandas(Index=591, gender='male', _2=71, _3=62, _4=50)
# Pandas(Index=592, gender='male', _2=68, _3=68, _4=64)
# Pandas(Index=593, gender='female', _2=74, _3=76, _4=73)
# Pandas(Index=594, gender='female', _2=92, _3=100, _4=99)
# Pandas(Index=595, gender='female', _2=56, _3=79, _4=72)
# Pandas(Index=596, gender='male', _2=30, _3=24, _4=15)
# Pandas(Index=597, gender='male', _2=53, _3=54, _4=48)
# Pandas(Index=598, gender='female', _2=69, _3=77, _4=73)
# Pandas(Index=599, gender='female', _2=65, _3=82, _4=81)
# Pandas(Index=600, gender='female', _2=54, _3=60, _4=63)
# Pandas(Index=601, gender='female', _2=29, _3=29, _4=30)
# Pandas(Index=602, gender='female', _2=76, _3=78, _4=80)
# Pandas(Index=603, gender='male', _2=60, _3=57, _4=51)
# Pandas(Index=604, gender='male', _2=84, _3=89, _4=90)
# Pandas(Index=605, gender='male', _2=75, _3=72, _4=62)
# Pandas(Index=606, gender='female', _2=85, _3=84, _4=82)
# Pandas(Index=607, gender='female', _2=40, _3=58, _4=54)
# Pandas(Index=608, gender='female', _2=61, _3=64, _4=62)
# Pandas(Index=609, gender='female', _2=58, _3=63, _4=65)
# Pandas(Index=610, gender='male', _2=69, _3=60, _4=63)
# Pandas(Index=611, gender='female', _2=58, _3=59, _4=66)
# Pandas(Index=612, gender='male', _2=94, _3=90, _4=91)
# Pandas(Index=613, gender='female', _2=65, _3=77, _4=74)
# Pandas(Index=614, gender='female', _2=82, _3=93, _4=93)
# Pandas(Index=615, gender='female', _2=60, _3=68, _4=72)
# Pandas(Index=616, gender='female', _2=37, _3=45, _4=38)
# Pandas(Index=617, gender='male', _2=88, _3=78, _4=83)
# Pandas(Index=618, gender='male', _2=95, _3=81, _4=84)
# Pandas(Index=619, gender='male', _2=65, _3=73, _4=68)
# Pandas(Index=620, gender='female', _2=35, _3=61, _4=54)
# Pandas(Index=621, gender='male', _2=62, _3=63, _4=56)
# Pandas(Index=622, gender='male', _2=58, _3=51, _4=52)
# Pandas(Index=623, gender='male', _2=100, _3=96, _4=86)
# Pandas(Index=624, gender='female', _2=61, _3=58, _4=62)
# Pandas(Index=625, gender='male', _2=100, _3=97, _4=99)
# Pandas(Index=626, gender='male', _2=69, _3=70, _4=63)
# Pandas(Index=627, gender='male', _2=61, _3=48, _4=46)
# Pandas(Index=628, gender='male', _2=49, _3=57, _4=46)
# Pandas(Index=629, gender='female', _2=44, _3=51, _4=55)
# Pandas(Index=630, gender='male', _2=67, _3=64, _4=70)
# Pandas(Index=631, gender='male', _2=79, _3=60, _4=65)
# Pandas(Index=632, gender='female', _2=66, _3=74, _4=81)
# Pandas(Index=633, gender='female', _2=75, _3=88, _4=85)
# Pandas(Index=634, gender='male', _2=84, _3=84, _4=80)
# Pandas(Index=635, gender='male', _2=71, _3=74, _4=64)
# Pandas(Index=636, gender='female', _2=67, _3=80, _4=81)
# Pandas(Index=637, gender='female', _2=80, _3=92, _4=88)
# Pandas(Index=638, gender='male', _2=86, _3=76, _4=74)
# Pandas(Index=639, gender='female', _2=76, _3=74, _4=73)
# Pandas(Index=640, gender='male', _2=41, _3=52, _4=51)
# Pandas(Index=641, gender='female', _2=74, _3=88, _4=90)
# Pandas(Index=642, gender='female', _2=72, _3=81, _4=79)
# Pandas(Index=643, gender='female', _2=74, _3=79, _4=80)
# Pandas(Index=644, gender='male', _2=70, _3=65, _4=60)
# Pandas(Index=645, gender='female', _2=65, _3=81, _4=81)
# Pandas(Index=646, gender='female', _2=59, _3=70, _4=65)
# Pandas(Index=647, gender='female', _2=64, _3=62, _4=68)
# Pandas(Index=648, gender='female', _2=50, _3=53, _4=55)
# Pandas(Index=649, gender='female', _2=69, _3=79, _4=81)
# Pandas(Index=650, gender='male', _2=51, _3=56, _4=53)
# Pandas(Index=651, gender='female', _2=68, _3=80, _4=76)
# Pandas(Index=652, gender='female', _2=85, _3=86, _4=98)
# Pandas(Index=653, gender='female', _2=65, _3=70, _4=74)
# Pandas(Index=654, gender='female', _2=73, _3=79, _4=79)
# Pandas(Index=655, gender='female', _2=62, _3=67, _4=67)
# Pandas(Index=656, gender='male', _2=77, _3=67, _4=64)
# Pandas(Index=657, gender='male', _2=69, _3=66, _4=61)
# Pandas(Index=658, gender='female', _2=43, _3=60, _4=58)
# Pandas(Index=659, gender='male', _2=90, _3=87, _4=85)
# Pandas(Index=660, gender='male', _2=74, _3=77, _4=73)
# Pandas(Index=661, gender='male', _2=73, _3=66, _4=63)
# Pandas(Index=662, gender='female', _2=55, _3=71, _4=69)
# Pandas(Index=663, gender='female', _2=65, _3=69, _4=67)
# Pandas(Index=664, gender='male', _2=80, _3=63, _4=63)
# Pandas(Index=665, gender='female', _2=50, _3=60, _4=60)
# Pandas(Index=666, gender='female', _2=63, _3=73, _4=71)
# Pandas(Index=667, gender='female', _2=77, _3=85, _4=87)
# Pandas(Index=668, gender='male', _2=73, _3=74, _4=61)
# Pandas(Index=669, gender='male', _2=81, _3=72, _4=77)
# Pandas(Index=670, gender='female', _2=66, _3=76, _4=68)
# Pandas(Index=671, gender='male', _2=52, _3=57, _4=50)
# Pandas(Index=672, gender='female', _2=69, _3=78, _4=76)
# Pandas(Index=673, gender='female', _2=65, _3=84, _4=84)
# Pandas(Index=674, gender='female', _2=69, _3=77, _4=78)
# Pandas(Index=675, gender='female', _2=50, _3=64, _4=66)
# Pandas(Index=676, gender='female', _2=73, _3=78, _4=76)
# Pandas(Index=677, gender='female', _2=70, _3=82, _4=76)
# Pandas(Index=678, gender='male', _2=81, _3=75, _4=78)
# Pandas(Index=679, gender='male', _2=63, _3=61, _4=60)
# Pandas(Index=680, gender='female', _2=67, _3=72, _4=74)
# Pandas(Index=681, gender='male', _2=60, _3=68, _4=60)
# Pandas(Index=682, gender='male', _2=62, _3=55, _4=54)
# Pandas(Index=683, gender='female', _2=29, _3=40, _4=44)
# Pandas(Index=684, gender='male', _2=62, _3=66, _4=68)
# Pandas(Index=685, gender='female', _2=94, _3=99, _4=100)
# Pandas(Index=686, gender='male', _2=85, _3=75, _4=68)
# Pandas(Index=687, gender='male', _2=77, _3=78, _4=73)
# Pandas(Index=688, gender='male', _2=53, _3=58, _4=44)
# Pandas(Index=689, gender='male', _2=93, _3=90, _4=83)
# Pandas(Index=690, gender='female', _2=49, _3=53, _4=53)
# Pandas(Index=691, gender='female', _2=73, _3=76, _4=78)
# Pandas(Index=692, gender='female', _2=66, _3=74, _4=81)
# Pandas(Index=693, gender='female', _2=77, _3=77, _4=73)
# Pandas(Index=694, gender='female', _2=49, _3=63, _4=56)
# Pandas(Index=695, gender='female', _2=79, _3=89, _4=86)
# Pandas(Index=696, gender='female', _2=75, _3=82, _4=90)
# Pandas(Index=697, gender='female', _2=59, _3=72, _4=70)
# Pandas(Index=698, gender='female', _2=57, _3=78, _4=79)
# Pandas(Index=699, gender='male', _2=66, _3=66, _4=59)
# Pandas(Index=700, gender='female', _2=79, _3=81, _4=82)
# Pandas(Index=701, gender='female', _2=57, _3=67, _4=72)
# Pandas(Index=702, gender='male', _2=87, _3=84, _4=87)
# Pandas(Index=703, gender='female', _2=63, _3=64, _4=67)
# Pandas(Index=704, gender='female', _2=59, _3=63, _4=64)
# Pandas(Index=705, gender='male', _2=62, _3=72, _4=65)
# Pandas(Index=706, gender='male', _2=46, _3=34, _4=36)
# Pandas(Index=707, gender='male', _2=66, _3=59, _4=52)
# Pandas(Index=708, gender='male', _2=89, _3=87, _4=79)
# Pandas(Index=709, gender='female', _2=42, _3=61, _4=58)
# Pandas(Index=710, gender='male', _2=93, _3=84, _4=90)
# Pandas(Index=711, gender='female', _2=80, _3=85, _4=85)
# Pandas(Index=712, gender='female', _2=98, _3=100, _4=99)
# Pandas(Index=713, gender='male', _2=81, _3=81, _4=84)
# Pandas(Index=714, gender='female', _2=60, _3=70, _4=74)
# Pandas(Index=715, gender='female', _2=76, _3=94, _4=87)
# Pandas(Index=716, gender='male', _2=73, _3=78, _4=72)
# Pandas(Index=717, gender='female', _2=96, _3=96, _4=99)
# Pandas(Index=718, gender='female', _2=76, _3=76, _4=74)
# Pandas(Index=719, gender='male', _2=91, _3=73, _4=80)
# Pandas(Index=720, gender='female', _2=62, _3=72, _4=70)
# Pandas(Index=721, gender='male', _2=55, _3=59, _4=59)
# Pandas(Index=722, gender='female', _2=74, _3=90, _4=88)
# Pandas(Index=723, gender='male', _2=50, _3=48, _4=42)
# Pandas(Index=724, gender='male', _2=47, _3=43, _4=41)
# Pandas(Index=725, gender='male', _2=81, _3=74, _4=71)
# Pandas(Index=726, gender='female', _2=65, _3=75, _4=77)
# Pandas(Index=727, gender='male', _2=68, _3=51, _4=57)
# Pandas(Index=728, gender='female', _2=73, _3=92, _4=84)
# Pandas(Index=729, gender='male', _2=53, _3=39, _4=37)
# Pandas(Index=730, gender='female', _2=68, _3=77, _4=80)
# Pandas(Index=731, gender='male', _2=55, _3=46, _4=43)
# Pandas(Index=732, gender='female', _2=87, _3=89, _4=94)
# Pandas(Index=733, gender='male', _2=55, _3=47, _4=44)
# Pandas(Index=734, gender='female', _2=53, _3=58, _4=57)
# Pandas(Index=735, gender='male', _2=67, _3=57, _4=59)
# Pandas(Index=736, gender='male', _2=92, _3=79, _4=84)
# Pandas(Index=737, gender='female', _2=53, _3=66, _4=73)
# Pandas(Index=738, gender='male', _2=81, _3=71, _4=73)
# Pandas(Index=739, gender='male', _2=61, _3=60, _4=55)
# Pandas(Index=740, gender='male', _2=80, _3=73, _4=72)
# Pandas(Index=741, gender='female', _2=37, _3=57, _4=56)
# Pandas(Index=742, gender='female', _2=81, _3=84, _4=82)
# Pandas(Index=743, gender='female', _2=59, _3=73, _4=72)
# Pandas(Index=744, gender='male', _2=55, _3=55, _4=47)
# Pandas(Index=745, gender='male', _2=72, _3=79, _4=74)
# Pandas(Index=746, gender='male', _2=69, _3=75, _4=71)
# Pandas(Index=747, gender='male', _2=69, _3=64, _4=68)
# Pandas(Index=748, gender='female', _2=50, _3=60, _4=59)
# Pandas(Index=749, gender='male', _2=87, _3=84, _4=86)
# Pandas(Index=750, gender='male', _2=71, _3=69, _4=68)
# Pandas(Index=751, gender='male', _2=68, _3=72, _4=65)
# Pandas(Index=752, gender='male', _2=79, _3=77, _4=75)
# Pandas(Index=753, gender='female', _2=77, _3=90, _4=85)
# Pandas(Index=754, gender='male', _2=58, _3=55, _4=53)
# Pandas(Index=755, gender='female', _2=84, _3=95, _4=92)
# Pandas(Index=756, gender='male', _2=55, _3=58, _4=52)
# Pandas(Index=757, gender='male', _2=70, _3=68, _4=72)
# Pandas(Index=758, gender='female', _2=52, _3=59, _4=65)
# Pandas(Index=759, gender='male', _2=69, _3=77, _4=77)
# Pandas(Index=760, gender='female', _2=53, _3=72, _4=64)
# Pandas(Index=761, gender='female', _2=48, _3=58, _4=54)
# Pandas(Index=762, gender='male', _2=78, _3=81, _4=86)
# Pandas(Index=763, gender='female', _2=62, _3=62, _4=63)
# Pandas(Index=764, gender='male', _2=60, _3=63, _4=59)
# Pandas(Index=765, gender='female', _2=74, _3=72, _4=72)
# Pandas(Index=766, gender='female', _2=58, _3=75, _4=77)
# Pandas(Index=767, gender='male', _2=76, _3=62, _4=60)
# Pandas(Index=768, gender='female', _2=68, _3=71, _4=75)
# Pandas(Index=769, gender='male', _2=58, _3=60, _4=57)
# Pandas(Index=770, gender='male', _2=52, _3=48, _4=49)
# Pandas(Index=771, gender='male', _2=75, _3=73, _4=74)
# Pandas(Index=772, gender='female', _2=52, _3=67, _4=72)
# Pandas(Index=773, gender='female', _2=62, _3=78, _4=79)
# Pandas(Index=774, gender='male', _2=66, _3=65, _4=60)
# Pandas(Index=775, gender='female', _2=49, _3=58, _4=55)
# Pandas(Index=776, gender='female', _2=66, _3=72, _4=70)
# Pandas(Index=777, gender='female', _2=35, _3=44, _4=43)
# Pandas(Index=778, gender='female', _2=72, _3=79, _4=82)
# Pandas(Index=779, gender='male', _2=94, _3=85, _4=82)
# Pandas(Index=780, gender='female', _2=46, _3=56, _4=57)
# Pandas(Index=781, gender='female', _2=77, _3=90, _4=84)
# Pandas(Index=782, gender='female', _2=76, _3=85, _4=82)
# Pandas(Index=783, gender='female', _2=52, _3=59, _4=62)
# Pandas(Index=784, gender='male', _2=91, _3=81, _4=79)
# Pandas(Index=785, gender='female', _2=32, _3=51, _4=44)
# Pandas(Index=786, gender='female', _2=72, _3=79, _4=77)
# Pandas(Index=787, gender='female', _2=19, _3=38, _4=32)
# Pandas(Index=788, gender='male', _2=68, _3=65, _4=61)
# Pandas(Index=789, gender='female', _2=52, _3=65, _4=61)
# Pandas(Index=790, gender='female', _2=48, _3=62, _4=60)
# Pandas(Index=791, gender='female', _2=60, _3=66, _4=70)
# Pandas(Index=792, gender='male', _2=66, _3=74, _4=69)
# Pandas(Index=793, gender='male', _2=89, _3=84, _4=77)
# Pandas(Index=794, gender='female', _2=42, _3=52, _4=51)
# Pandas(Index=795, gender='female', _2=57, _3=68, _4=73)
# Pandas(Index=796, gender='male', _2=70, _3=70, _4=70)
# Pandas(Index=797, gender='female', _2=70, _3=84, _4=81)
# Pandas(Index=798, gender='male', _2=69, _3=60, _4=54)
# Pandas(Index=799, gender='female', _2=52, _3=55, _4=57)
# Pandas(Index=800, gender='male', _2=67, _3=73, _4=68)
# Pandas(Index=801, gender='male', _2=76, _3=80, _4=73)
# Pandas(Index=802, gender='female', _2=87, _3=94, _4=95)
# Pandas(Index=803, gender='female', _2=82, _3=85, _4=87)
# Pandas(Index=804, gender='female', _2=73, _3=76, _4=78)
# Pandas(Index=805, gender='male', _2=75, _3=81, _4=74)
# Pandas(Index=806, gender='female', _2=64, _3=74, _4=75)
# Pandas(Index=807, gender='female', _2=41, _3=45, _4=40)
# Pandas(Index=808, gender='male', _2=90, _3=75, _4=69)
# Pandas(Index=809, gender='male', _2=59, _3=54, _4=51)
# Pandas(Index=810, gender='male', _2=51, _3=31, _4=36)
# Pandas(Index=811, gender='male', _2=45, _3=47, _4=49)
# Pandas(Index=812, gender='female', _2=54, _3=64, _4=67)
# Pandas(Index=813, gender='male', _2=87, _3=84, _4=76)
# Pandas(Index=814, gender='female', _2=72, _3=80, _4=83)
# Pandas(Index=815, gender='male', _2=94, _3=86, _4=87)
# Pandas(Index=816, gender='female', _2=45, _3=59, _4=64)
# Pandas(Index=817, gender='male', _2=61, _3=70, _4=76)
# Pandas(Index=818, gender='female', _2=60, _3=72, _4=68)
# Pandas(Index=819, gender='female', _2=77, _3=91, _4=88)
# Pandas(Index=820, gender='female', _2=85, _3=90, _4=92)
# Pandas(Index=821, gender='female', _2=78, _3=90, _4=93)
# Pandas(Index=822, gender='male', _2=49, _3=52, _4=51)
# Pandas(Index=823, gender='female', _2=71, _3=87, _4=82)
# Pandas(Index=824, gender='female', _2=48, _3=58, _4=52)
# Pandas(Index=825, gender='male', _2=62, _3=67, _4=58)
# Pandas(Index=826, gender='female', _2=56, _3=68, _4=70)
# Pandas(Index=827, gender='female', _2=65, _3=69, _4=76)
# Pandas(Index=828, gender='female', _2=69, _3=86, _4=81)
# Pandas(Index=829, gender='male', _2=68, _3=54, _4=53)
# Pandas(Index=830, gender='female', _2=61, _3=60, _4=57)
# Pandas(Index=831, gender='female', _2=74, _3=86, _4=89)
# Pandas(Index=832, gender='male', _2=64, _3=60, _4=58)
# Pandas(Index=833, gender='female', _2=77, _3=82, _4=89)
# Pandas(Index=834, gender='male', _2=58, _3=50, _4=45)
# Pandas(Index=835, gender='female', _2=60, _3=64, _4=74)
# Pandas(Index=836, gender='male', _2=73, _3=64, _4=57)
# Pandas(Index=837, gender='female', _2=75, _3=82, _4=79)
# Pandas(Index=838, gender='male', _2=58, _3=57, _4=53)
# Pandas(Index=839, gender='female', _2=66, _3=77, _4=73)
# Pandas(Index=840, gender='female', _2=39, _3=52, _4=46)
# Pandas(Index=841, gender='male', _2=64, _3=58, _4=51)
# Pandas(Index=842, gender='female', _2=23, _3=44, _4=36)
# Pandas(Index=843, gender='male', _2=74, _3=77, _4=76)
# Pandas(Index=844, gender='female', _2=40, _3=65, _4=64)
# Pandas(Index=845, gender='male', _2=90, _3=85, _4=84)
# Pandas(Index=846, gender='male', _2=91, _3=85, _4=85)
# Pandas(Index=847, gender='male', _2=64, _3=54, _4=50)
# Pandas(Index=848, gender='female', _2=59, _3=72, _4=68)
# Pandas(Index=849, gender='male', _2=80, _3=75, _4=69)
# Pandas(Index=850, gender='male', _2=71, _3=67, _4=67)
# Pandas(Index=851, gender='female', _2=61, _3=68, _4=63)
# Pandas(Index=852, gender='female', _2=87, _3=85, _4=93)
# Pandas(Index=853, gender='male', _2=82, _3=67, _4=61)
# Pandas(Index=854, gender='male', _2=62, _3=64, _4=55)
# Pandas(Index=855, gender='female', _2=97, _3=97, _4=96)
# Pandas(Index=856, gender='male', _2=75, _3=68, _4=65)
# Pandas(Index=857, gender='female', _2=65, _3=79, _4=81)
# Pandas(Index=858, gender='male', _2=52, _3=49, _4=46)
# Pandas(Index=859, gender='male', _2=87, _3=73, _4=72)
# Pandas(Index=860, gender='female', _2=53, _3=62, _4=53)
# Pandas(Index=861, gender='female', _2=81, _3=86, _4=87)
# Pandas(Index=862, gender='male', _2=39, _3=42, _4=38)
# Pandas(Index=863, gender='female', _2=71, _3=71, _4=80)
# Pandas(Index=864, gender='male', _2=97, _3=93, _4=91)
# Pandas(Index=865, gender='male', _2=82, _3=82, _4=88)
# Pandas(Index=866, gender='male', _2=59, _3=53, _4=52)
# Pandas(Index=867, gender='male', _2=61, _3=42, _4=41)
# Pandas(Index=868, gender='male', _2=78, _3=74, _4=72)
# Pandas(Index=869, gender='male', _2=49, _3=51, _4=51)
# Pandas(Index=870, gender='male', _2=59, _3=58, _4=47)
# Pandas(Index=871, gender='female', _2=70, _3=72, _4=76)
# Pandas(Index=872, gender='male', _2=82, _3=84, _4=78)
# Pandas(Index=873, gender='male', _2=90, _3=90, _4=82)
# Pandas(Index=874, gender='female', _2=43, _3=62, _4=61)
# Pandas(Index=875, gender='male', _2=80, _3=64, _4=66)
# Pandas(Index=876, gender='male', _2=81, _3=82, _4=84)
# Pandas(Index=877, gender='male', _2=57, _3=61, _4=54)
# Pandas(Index=878, gender='female', _2=59, _3=72, _4=80)
# Pandas(Index=879, gender='female', _2=64, _3=76, _4=74)
# Pandas(Index=880, gender='male', _2=63, _3=64, _4=66)
# Pandas(Index=881, gender='female', _2=71, _3=70, _4=70)
# Pandas(Index=882, gender='female', _2=64, _3=73, _4=71)
# Pandas(Index=883, gender='male', _2=55, _3=46, _4=44)
# Pandas(Index=884, gender='female', _2=51, _3=51, _4=54)
# Pandas(Index=885, gender='female', _2=62, _3=76, _4=80)
# Pandas(Index=886, gender='female', _2=93, _3=100, _4=95)
# Pandas(Index=887, gender='male', _2=54, _3=72, _4=59)
# Pandas(Index=888, gender='female', _2=69, _3=65, _4=74)
# Pandas(Index=889, gender='male', _2=44, _3=51, _4=48)
# Pandas(Index=890, gender='female', _2=86, _3=85, _4=91)
# Pandas(Index=891, gender='female', _2=85, _3=92, _4=85)
# Pandas(Index=892, gender='female', _2=50, _3=67, _4=73)
# Pandas(Index=893, gender='male', _2=88, _3=74, _4=75)
# Pandas(Index=894, gender='female', _2=59, _3=62, _4=69)
# Pandas(Index=895, gender='female', _2=32, _3=34, _4=38)
# Pandas(Index=896, gender='male', _2=36, _3=29, _4=27)
# Pandas(Index=897, gender='female', _2=63, _3=78, _4=79)
# Pandas(Index=898, gender='male', _2=67, _3=54, _4=63)
# Pandas(Index=899, gender='female', _2=65, _3=78, _4=82)
# Pandas(Index=900, gender='male', _2=85, _3=84, _4=89)
# Pandas(Index=901, gender='female', _2=73, _3=78, _4=74)
# Pandas(Index=902, gender='female', _2=34, _3=48, _4=41)
# Pandas(Index=903, gender='female', _2=93, _3=100, _4=100)
# Pandas(Index=904, gender='female', _2=67, _3=84, _4=84)
# Pandas(Index=905, gender='male', _2=88, _3=77, _4=77)
# Pandas(Index=906, gender='male', _2=57, _3=48, _4=51)
# Pandas(Index=907, gender='female', _2=79, _3=84, _4=91)
# Pandas(Index=908, gender='female', _2=67, _3=75, _4=72)
# Pandas(Index=909, gender='male', _2=70, _3=64, _4=70)
# Pandas(Index=910, gender='male', _2=50, _3=42, _4=48)
# Pandas(Index=911, gender='female', _2=69, _3=84, _4=82)
# Pandas(Index=912, gender='female', _2=52, _3=61, _4=66)
# Pandas(Index=913, gender='female', _2=47, _3=62, _4=66)
# Pandas(Index=914, gender='female', _2=46, _3=61, _4=55)
# Pandas(Index=915, gender='female', _2=68, _3=70, _4=66)
# Pandas(Index=916, gender='male', _2=100, _3=100, _4=100)
# Pandas(Index=917, gender='female', _2=44, _3=61, _4=52)
# Pandas(Index=918, gender='female', _2=57, _3=77, _4=80)
# Pandas(Index=919, gender='male', _2=91, _3=96, _4=91)
# Pandas(Index=920, gender='male', _2=69, _3=70, _4=67)
# Pandas(Index=921, gender='female', _2=35, _3=53, _4=46)
# Pandas(Index=922, gender='male', _2=72, _3=66, _4=66)
# Pandas(Index=923, gender='female', _2=54, _3=65, _4=65)
# Pandas(Index=924, gender='male', _2=74, _3=70, _4=69)
# Pandas(Index=925, gender='male', _2=74, _3=64, _4=60)
# Pandas(Index=926, gender='male', _2=64, _3=56, _4=52)
# Pandas(Index=927, gender='female', _2=65, _3=61, _4=71)
# Pandas(Index=928, gender='male', _2=46, _3=43, _4=44)
# Pandas(Index=929, gender='female', _2=48, _3=56, _4=51)
# Pandas(Index=930, gender='male', _2=67, _3=74, _4=70)
# Pandas(Index=931, gender='male', _2=62, _3=57, _4=62)
# Pandas(Index=932, gender='male', _2=61, _3=71, _4=73)
# Pandas(Index=933, gender='male', _2=70, _3=75, _4=74)
# Pandas(Index=934, gender='male', _2=98, _3=87, _4=90)
# Pandas(Index=935, gender='male', _2=70, _3=63, _4=58)
# Pandas(Index=936, gender='male', _2=67, _3=57, _4=53)
# Pandas(Index=937, gender='female', _2=57, _3=58, _4=57)
# Pandas(Index=938, gender='male', _2=85, _3=81, _4=85)
# Pandas(Index=939, gender='male', _2=77, _3=68, _4=69)
# Pandas(Index=940, gender='male', _2=72, _3=66, _4=72)
# Pandas(Index=941, gender='female', _2=78, _3=91, _4=96)
# Pandas(Index=942, gender='male', _2=81, _3=66, _4=64)
# Pandas(Index=943, gender='male', _2=61, _3=62, _4=61)
# Pandas(Index=944, gender='female', _2=58, _3=68, _4=61)
# Pandas(Index=945, gender='female', _2=54, _3=61, _4=58)
# Pandas(Index=946, gender='male', _2=82, _3=82, _4=80)
# Pandas(Index=947, gender='female', _2=49, _3=58, _4=60)
# Pandas(Index=948, gender='male', _2=49, _3=50, _4=52)
# Pandas(Index=949, gender='female', _2=57, _3=75, _4=73)
# Pandas(Index=950, gender='male', _2=94, _3=73, _4=71)
# Pandas(Index=951, gender='female', _2=75, _3=77, _4=83)
# Pandas(Index=952, gender='female', _2=74, _3=74, _4=72)
# Pandas(Index=953, gender='male', _2=58, _3=52, _4=54)
# Pandas(Index=954, gender='female', _2=62, _3=69, _4=69)
# Pandas(Index=955, gender='male', _2=72, _3=57, _4=62)
# Pandas(Index=956, gender='male', _2=84, _3=87, _4=81)
# Pandas(Index=957, gender='female', _2=92, _3=100, _4=100)
# Pandas(Index=958, gender='female', _2=45, _3=63, _4=59)
# Pandas(Index=959, gender='male', _2=75, _3=81, _4=71)
# Pandas(Index=960, gender='female', _2=56, _3=58, _4=64)
# Pandas(Index=961, gender='female', _2=48, _3=54, _4=53)
# Pandas(Index=962, gender='female', _2=100, _3=100, _4=100)
# Pandas(Index=963, gender='female', _2=65, _3=76, _4=75)
# Pandas(Index=964, gender='male', _2=72, _3=57, _4=58)
# Pandas(Index=965, gender='female', _2=62, _3=70, _4=72)
# Pandas(Index=966, gender='male', _2=66, _3=68, _4=64)
# Pandas(Index=967, gender='male', _2=63, _3=63, _4=60)
# Pandas(Index=968, gender='female', _2=68, _3=76, _4=67)
# Pandas(Index=969, gender='female', _2=75, _3=84, _4=80)
# Pandas(Index=970, gender='female', _2=89, _3=100, _4=100)
# Pandas(Index=971, gender='male', _2=78, _3=72, _4=69)
# Pandas(Index=972, gender='female', _2=53, _3=50, _4=60)
# Pandas(Index=973, gender='female', _2=49, _3=65, _4=61)
# Pandas(Index=974, gender='female', _2=54, _3=63, _4=67)
# Pandas(Index=975, gender='female', _2=64, _3=82, _4=77)
# Pandas(Index=976, gender='male', _2=60, _3=62, _4=60)
# Pandas(Index=977, gender='male', _2=62, _3=65, _4=58)
# Pandas(Index=978, gender='male', _2=55, _3=41, _4=48)
# Pandas(Index=979, gender='female', _2=91, _3=95, _4=94)
# Pandas(Index=980, gender='female', _2=8, _3=24, _4=23)
# Pandas(Index=981, gender='male', _2=81, _3=78, _4=78)
# Pandas(Index=982, gender='male', _2=79, _3=85, _4=86)
# Pandas(Index=983, gender='female', _2=78, _3=87, _4=91)
# Pandas(Index=984, gender='female', _2=74, _3=75, _4=82)
# Pandas(Index=985, gender='male', _2=57, _3=51, _4=54)
# Pandas(Index=986, gender='female', _2=40, _3=59, _4=51)
# Pandas(Index=987, gender='male', _2=81, _3=75, _4=76)
# Pandas(Index=988, gender='female', _2=44, _3=45, _4=45)
# Pandas(Index=989, gender='female', _2=67, _3=86, _4=83)
# Pandas(Index=990, gender='male', _2=86, _3=81, _4=75)
# Pandas(Index=991, gender='female', _2=65, _3=82, _4=78)
# Pandas(Index=992, gender='female', _2=55, _3=76, _4=76)
# Pandas(Index=993, gender='female', _2=62, _3=72, _4=74)
# Pandas(Index=994, gender='male', _2=63, _3=63, _4=62)
# Pandas(Index=995, gender='female', _2=88, _3=99, _4=95)
# Pandas(Index=996, gender='male', _2=62, _3=55, _4=55)
# Pandas(Index=997, gender='female', _2=59, _3=71, _4=65)
# Pandas(Index=998, gender='female', _2=68, _3=78, _4=77)
# Pandas(Index=999, gender='female', _2=77, _3=86, _4=86)

# %%
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score'], dtype='object')

# %%
for row in df.itertuples():
    print(row.gender)
# Out:
# female
# female
# female
# male
# male
# female
# female
# male
# male
# female
# male
# male
# female
# male
# female
# female
# male
# female
# male
# female
# male
# female
# male
# female
# male
# male
# male
# female
# male
# female
# female
# female
# female
# male
# male
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# male
# female
# female
# female
# male
# male
# male
# male
# male
# female
# female
# female
# male
# male
# female
# male
# male
# male
# female
# female
# male
# male
# female
# male
# female
# female
# male
# female
# male
# male
# male
# male
# male
# female
# female
# female
# male
# male
# male
# male
# female
# female
# female
# female
# female
# female
# male
# male
# male
# female
# male
# male
# female
# female
# female
# male
# male
# female
# male
# male
# female
# female
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# female
# female
# female
# female
# male
# female
# male
# male
# female
# male
# male
# male
# female
# male
# male
# male
# female
# male
# male
# male
# male
# female
# male
# female
# female
# female
# male
# male
# female
# male
# male
# female
# male
# male
# male
# female
# male
# male
# female
# female
# male
# female
# male
# male
# female
# male
# male
# female
# female
# male
# female
# female
# female
# male
# male
# female
# female
# female
# female
# female
# female
# female
# female
# male
# female
# female
# female
# male
# male
# male
# male
# male
# female
# female
# male
# female
# male
# female
# male
# male
# male
# female
# female
# female
# female
# male
# female
# male
# male
# male
# male
# female
# female
# male
# male
# female
# male
# male
# male
# female
# female
# male
# male
# female
# male
# female
# male
# female
# female
# female
# male
# male
# female
# male
# male
# female
# male
# male
# male
# male
# female
# male
# male
# male
# female
# female
# male
# male
# male
# male
# female
# female
# male
# male
# female
# female
# male
# male
# female
# female
# male
# female
# female
# female
# male
# female
# female
# male
# male
# female
# female
# female
# female
# male
# male
# female
# female
# male
# male
# female
# female
# female
# male
# male
# male
# female
# female
# female
# male
# male
# female
# male
# male
# male
# male
# male
# female
# male
# male
# male
# male
# male
# male
# male
# male
# female
# male
# female
# male
# male
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# male
# male
# female
# female
# female
# female
# female
# female
# female
# male
# male
# male
# female
# male
# male
# male
# male
# female
# female
# male
# male
# female
# female
# male
# female
# female
# male
# male
# female
# male
# female
# male
# male
# female
# male
# female
# female
# female
# female
# male
# female
# male
# female
# female
# male
# female
# female
# male
# male
# male
# male
# female
# female
# male
# female
# male
# female
# female
# male
# female
# female
# female
# male
# female
# male
# male
# female
# female
# female
# female
# female
# female
# male
# male
# female
# male
# male
# female
# male
# female
# female
# male
# male
# female
# male
# female
# female
# female
# female
# male
# female
# female
# male
# female
# male
# male
# male
# female
# male
# male
# male
# male
# male
# female
# female
# female
# female
# male
# female
# male
# male
# male
# male
# male
# female
# male
# female
# male
# male
# male
# male
# male
# male
# female
# female
# female
# female
# male
# female
# male
# male
# male
# male
# female
# female
# female
# male
# female
# male
# female
# male
# female
# male
# male
# male
# female
# female
# male
# female
# female
# male
# female
# male
# female
# female
# female
# female
# female
# female
# male
# male
# female
# male
# male
# female
# male
# male
# female
# male
# male
# female
# male
# male
# female
# female
# female
# female
# female
# male
# female
# female
# female
# male
# female
# female
# male
# female
# female
# female
# male
# male
# male
# female
# male
# male
# male
# female
# female
# female
# female
# female
# female
# female
# male
# female
# male
# male
# male
# male
# male
# female
# female
# female
# female
# female
# male
# female
# male
# female
# male
# female
# male
# male
# male
# male
# female
# female
# female
# male
# female
# male
# female
# male
# male
# male
# female
# male
# male
# female
# female
# male
# female
# male
# female
# female
# male
# female
# male
# male
# female
# female
# male
# male
# male
# male
# female
# female
# female
# male
# male
# female
# female
# female
# female
# female
# female
# female
# female
# female
# female
# female
# female
# female
# male
# male
# male
# female
# female
# female
# male
# male
# female
# female
# female
# female
# female
# male
# male
# male
# female
# female
# female
# female
# male
# female
# male
# female
# female
# female
# female
# male
# male
# male
# female
# male
# male
# male
# female
# male
# male
# male
# male
# female
# male
# male
# female
# female
# male
# male
# female
# female
# male
# female
# male
# female
# female
# female
# male
# female
# female
# female
# female
# female
# male
# female
# female
# female
# female
# female
# male
# male
# female
# male
# male
# male
# female
# female
# male
# female
# female
# female
# male
# male
# female
# male
# female
# female
# female
# female
# female
# female
# male
# male
# female
# male
# male
# female
# male
# female
# male
# male
# male
# male
# female
# female
# female
# female
# female
# female
# female
# female
# female
# male
# female
# female
# male
# female
# female
# male
# male
# male
# male
# female
# male
# female
# female
# male
# female
# female
# male
# female
# female
# male
# female
# male
# female
# male
# male
# male
# female
# male
# female
# male
# female
# male
# female
# male
# female
# male
# male
# female
# male
# male
# male
# female
# female
# female
# male
# male
# male
# male
# female
# male
# male
# male
# male
# female
# male
# female
# male
# male
# female
# male
# female
# female
# male
# female
# male
# female
# female
# male
# female
# male
# male
# male
# female
# female
# male
# female
# female
# female
# female
# male
# female
# female
# female
# female
# male
# female
# female
# female
# male
# female
# female
# female
# male
# male
# female
# female
# male
# female
# male
# female
# male
# male
# female
# female
# female
# male
# female
# female
# male
# male
# male
# male
# female
# male
# female
# male
# female
# male
# female
# female
# female
# female
# male
# female
# female
# male
# female
# female
# female
# male
# female
# female
# male
# female
# male
# female
# male
# female
# male
# female
# female
# male
# female
# male
# female
# male
# male
# male
# female
# male
# male
# female
# female
# male
# male
# female
# male
# female
# male
# male
# female
# female
# male
# female
# male
# male
# male
# male
# male
# male
# male
# female
# male
# male
# female
# male
# male
# male
# female
# female
# male
# female
# female
# male
# female
# female
# female
# male
# female
# male
# female
# female
# female
# male
# female
# female
# male
# female
# male
# female
# male
# female
# female
# female
# female
# male
# male
# female
# female
# male
# male
# female
# female
# female
# female
# female
# male
# female
# female
# male
# male
# female
# male
# female
# male
# male
# male
# female
# male
# female
# male
# male
# male
# male
# male
# male
# male
# female
# male
# male
# male
# female
# male
# male
# female
# female
# male
# female
# male
# female
# male
# female
# female
# male
# female
# male
# male
# female
# female
# male
# female
# female
# female
# female
# male
# female
# male
# male
# female
# female
# female
# male
# female
# female
# female
# female
# male
# male
# male
# female
# female
# male
# male
# female
# female
# male
# female
# male
# female
# female
# male
# female
# female
# female
# male
# female
# male
# female
# female
# female

# %%
df.columns = [col.lower() for col in df]
df.columns
# Out:
# Index(['gender', 'math score', 'reading score', 'writing score'], dtype='object')

# %%
df.rename(columns={
        'math score': 'math_score',
        'reading score': 'reading_score',
        'writing score': 'writing_score',
    }, inplace=True
)

df
# Out:
#      gender  math_score  reading_score  writing_score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]
